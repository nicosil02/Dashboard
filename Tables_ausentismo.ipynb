# %% [markdown]
# # Table Ausentismo

# %%
import pandas as pd
data=pd.read_csv("elecciones_18_22.csv")

# %%
data
# Out:
#         Region    Provincia       Distrito  Ubigeo  Votosemitidos  Electores  \
# 0     AMAZONAS  CHACHAPOYAS       ASUNCION   10102          267.0      170.0
# 1     AMAZONAS  CHACHAPOYAS         BALSAS   10103          538.0      264.0
# 2     AMAZONAS  CHACHAPOYAS         BALSAS   10103          538.0      265.0
# 3     AMAZONAS  CHACHAPOYAS          CHETO   10104          514.0      214.0
# 4     AMAZONAS  CHACHAPOYAS          CHETO   10104          514.0      215.0
# ...        ...          ...            ...     ...            ...        ...
# 6227   UCAYALI      ATALAYA       TAHUANIA  250302         2468.0      230.0
# 6228   UCAYALI      ATALAYA       TAHUANIA  250302         2468.0      286.0
# 6229   UCAYALI      ATALAYA       TAHUANIA  250302         2468.0      287.0
# 6230   UCAYALI      ATALAYA          YURUA  250303          672.0      238.0
# 6231     PIURA     MORROPON  SANTO DOMINGO  190407         4010.0      199.0
#
# ...

# %%
cortes = pd.qcut(data["P_ausentismo"], q=3, labels=["Bajo", "Medio", "Alto"])
data["nivel_ausentismo"] = cortes
